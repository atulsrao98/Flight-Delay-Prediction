# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# c:\python37\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# c:\python37\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# c:\python37\lib\site-packages\numpy\.libs\libopenblas.TXA6YQSD3GCQQC22GEQ54J2UDCXDXHWN.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
data1=pd.read_csv(r"D:\Downloads\flight_delay_prediction\flights.csv\flights.csv")
# Out:
# c:\python37\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
len(data1)
# Out:
# 5819079

# %%
data1.describe()
# Out:
#             YEAR         MONTH           DAY   DAY_OF_WEEK  FLIGHT_NUMBER  \
# count  5819079.0  5.819079e+06  5.819079e+06  5.819079e+06   5.819079e+06
# mean      2015.0  6.524085e+00  1.570459e+01  3.926941e+00   2.173093e+03
# std          0.0  3.405137e+00  8.783425e+00  1.988845e+00   1.757064e+03
# min       2015.0  1.000000e+00  1.000000e+00  1.000000e+00   1.000000e+00
# 25%       2015.0  4.000000e+00  8.000000e+00  2.000000e+00   7.300000e+02
# 50%       2015.0  7.000000e+00  1.600000e+01  4.000000e+00   1.690000e+03
# 75%       2015.0  9.000000e+00  2.300000e+01  6.000000e+00   3.230000e+03
# max       2015.0  1.200000e+01  3.100000e+01  7.000000e+00   9.855000e+03
#
#        SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY      TAXI_OUT  \
# count         5.819079e+06    5.732926e+06     5.732926e+06  5.730032e+06
# mean          1.329602e+03    1.335204e+03     9.370158e+00  1.607166e+01
# std           4.837518e+02    4.964233e+02     3.708094e+01  8.895574e+00
# ...

# %%
data1.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 0            ANC                 SEA                    5  ...         408.0
# 1            LAX                 PBI                   10  ...         741.0
# 2            SFO                 CLT                   20  ...         811.0
# 3            LAX                 MIA                   20  ...         756.0
# 4            SEA                 ANC                   25  ...         259.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# ...

# %%
data1['DELAYED']=Y
data3=data1.groupby(['AIRLINE','DELAYED'])

# %%
data3.size().unstack()
# Out:
# DELAYED       0       1
# AIRLINE
# AA       446655  279329
# AS       110162   62359
# B6       155170  111878
# DL       601859  274022
# EV       328301  243676
# F9        46873   43963
# HA        42545   33727
# MQ       170102  124530
# NK        55893   61486
# OO       339967  248386
# UA       312159  203564
# US       113399   85316
# VX        35482   26421
# WN       742332  519523

# %%
df_aircode1=pd.read_csv(r'D:\Downloads\flightdelay-master\airportcodes\L_AIRPORT.csv')
df_aircode2 = pd.read_csv(r'D:\Downloads\flightdelay-master\airportcodes\L_AIRPORT_ID.csv')

# %%
import seaborn as srs
srs.barplot(x='DEPARTURE_DELAY',y='AIRLINE',data=data1,color='black',ci=None)
srs.barplot(x='ARRIVAL_DELAY',y='AIRLINE',data=data1,color='red',hatch='///',ci=None)

df_aircode1 = df_aircode1.reset_index()
df_aircode2 = df_aircode2.reset_index()
df_aircodes = pd.merge(df_aircode1,df_aircode2,on='Description')
aircode_dict = dict(zip(df_aircodes['Code_y'].astype(str),df_aircodes['Code_x']))

# %%
data1['ORIGIN_AIRPORT'] = data1['ORIGIN_AIRPORT'].values.astype(str)
data1['DESTINATION_AIRPORT'] = data1['DESTINATION_AIRPORT'].values.astype(str)

N_flights = len(data1)
for i in range(N_flights):
    if i % 100000 == 0:
        print(i)
    if len(data1['ORIGIN_AIRPORT'][i]) != 3:
        to_replace = data1['ORIGIN_AIRPORT'][i]
        value = aircode_dict[data1['ORIGIN_AIRPORT'][i]]
        data1 = data1.replace(to_replace, value)
        print('replaced',to_replace,'with',value)
    if len(data1['DESTINATION_AIRPORT'][i]) != 3:
        to_replace = data1['DESTINATION_AIRPORT'][i]
        value = aircode_dict[data1['DESTINATION_AIRPORT'][i]]
        data1 = data1.replace(to_replace, value)
        print('replaced',to_replace,'with',value)
# Out:
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# 1200000
# 1300000
# 1400000
# 1500000
# 1600000
# 1700000
# 1800000
# 1900000
# 2000000
# 2100000
# 2200000
# 2300000
# 2400000
# 2500000
# 2600000
# 2700000
# 2800000
# 2900000
# 3000000
# 3100000
# 3200000
# 3300000
# 3400000
# 3500000
# 3600000
# 3700000
# 3800000
# 3900000
# 4000000
# 4100000
# 4200000
# 4300000
# replaced 14747 with SEA
# replaced 11298 with DFW
# replaced 14771 with SFO
# replaced 13487 with MSP
# replaced 12889 with LAS
# replaced 12892 with LAX
# replaced 13303 with MIA
# replaced 11057 with CLT
# replaced 13930 with ORD
# replaced 14869 with SLC
# replaced 10693 with BNA
# replaced 10299 with ANC
# replaced 12266 with IAH
# replaced 11292 with DEN
# replaced 12478 with JFK
# replaced 14107 with PHX
# replaced 14057 with PDX
# replaced 10397 with ATL
# replaced 13198 with MCI
# replaced 11630 with FAI
# replaced 12173 with HNL
# replaced 10732 with BQN
# ...

# %%
dataset_copy=data1
dataset_copy.to_csv(r"D:\Downloads\flight_delay_prediction\flights.csv\flights1.csv")

# %%
dataset=dataset_copy

# %%
import seaborn 
data2=data1.groupby('DAY_OF_WEEK').sum().reset_index()
seaborn.barplot(x='DAY_OF_WEEK',y='ARRIVAL_DELAY',data=data2,color='blue',ci=None)

# %%
ax=seaborn.barplot(x='DAY_OF_WEEK',y='DEPARTURE_DELAY',data=data2,color='blue',ci=None)

# %%
plt.hist(data1['AIRLINE'])
plt.show()

# %%
dataset['ORIGIN_AIRPORT'].value_counts().plot(kind='barh',figsize=(10,50))

# %%
dataset['DAY'].value_counts().plot(kind='barh',figsize=(5,7))

# %%
dataset['MONTH'].value_counts().plot(kind='barh')

# %%
import seaborn
plt.figure(figsize=(6,50))
seaborn.barplot(x='DEPARTURE_DELAY',y='ORIGIN_AIRPORT',data=dataset)

# %%
plt.figure(figsize=(6,50))
seaborn.barplot(x='ARRIVAL_DELAY',y='DESTINATION_AIRPORT',data=dataset)

# %%
plt.figure(figsize=(10,10))
seaborn.barplot(x='DAY',y='DEPARTURE_DELAY',data=dataset)

# %%
plt.figure(figsize=(10,10))
seaborn.barplot(x='DAY',y='ARRIVAL_DELAY',data=dataset)

# %%
seaborn.barplot(x='MONTH',y='DEPARTURE_DELAY',data=dataset)

# %%
seaborn.barplot(x='MONTH',y='ARRIVAL_DELAY',data=dataset)

# %%
dataset=pd.read_csv(r"D:\Downloads\flight_delay_prediction\flights.csv\flights1.csv")

# %%
dataset=dataset.drop(dataset.columns[0],axis=1)

# %%
dataset=dataset.drop(['FLIGHT_NUMBER','TAIL_NUMBER'],axis=1)

# %%
dataset=dataset.drop(['YEAR','DAY_OF_WEEK','SCHEDULED_DEPARTURE','SCHEDULED_ARRIVAL','DIVERTED','CANCELLED','CANCELLATION_REASON','AIR_SYSTEM_DELAY','SECURITY_DELAY','AIRLINE_DELAY','LATE_AIRCRAFT_DELAY','WEATHER_DELAY'],axis=1)

# %%
dataset=dataset.drop(['DEPARTURE_TIME'],axis=1)

# %%
dataset.head()
# Out:
#    MONTH  DAY AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  DEPARTURE_DELAY  \
# 0      1    1      AS            ANC                 SEA            -11.0
# 1      1    1      AA            LAX                 PBI             -8.0
# 2      1    1      US            SFO                 CLT             -2.0
# 3      1    1      AA            LAX                 MIA             -5.0
# 4      1    1      AS            SEA                 ANC             -1.0
#
#    TAXI_OUT  WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  AIR_TIME  DISTANCE  \
# 0      21.0        15.0           205.0         194.0     169.0      1448
# 1      12.0        14.0           280.0         279.0     263.0      2330
# 2      16.0        34.0           286.0         293.0     266.0      2296
# 3      15.0        30.0           285.0         281.0     258.0      2342
# 4      11.0        35.0           235.0         215.0     199.0      1448
#
#    WHEELS_ON  TAXI_IN  ARRIVAL_TIME  ARRIVAL_DELAY
# ...

# %%
len(dataset)
# Out:
# 5819079

# %%
temp_target=[None]*len(dataset['ARRIVAL_DELAY'])
for i in range(len(dataset['ARRIVAL_DELAY'])):
    if dataset.loc[i,'ARRIVAL_DELAY'] < 0:
        temp_target[i]=0
    elif dataset.loc[i,'ARRIVAL_DELAY'] == 0:
        temp_target[i]=0
    elif np.isnan(dataset.loc[i,'ARRIVAL_DELAY']):
        temp_target[i]=np.nan
    else:
        temp_target[i]=1

# %%
dataset['DELAYED']=temp_target
dataset=dataset.drop('ARRIVAL_DELAY',axis=1)

# %%
dataset=dataset.dropna()

# %%
len(dataset)
# Out:
# 5714008

# %%
dataset['AIRLINE']=dataset['AIRLINE'].map({'AS':1, 'AA':2, 'US':3, 'DL':4, 'NK':5, 'UA':6, 'HA':7, 'B6':8, 'OO':9, 'EV':10, 'F9':11,'WN':12, 'MQ':13, 'VX':14})

# %%
dataset['ORIGIN_AIRPORT']=dataset['ORIGIN_AIRPORT'].map({'ANC':1, 'LAX':2, 'SFO':3, 'SEA':4, 'LAS':5, 'DEN':6, 'SLC':7, 'PDX':8, 'FAI':9,'MSP':10, 'PHX':11, 'SJU':12, 'PBG':13, 'IAG':14, 'PSE':15, 'BQN':16, 'ORD':17, 'GEG':18,
       'HNL':19, 'ONT':20, 'MCO':21, 'BOS':22, 'HIB':23, 'ABR':24, 'DFW':25, 'MKE':26, 'IAH':27,
       'BNA':28, 'BRO':29, 'VPS':30, 'BOI':31, 'BJI':32, 'PHL':33, 'SBN':34, 'EUG':35, 'IAD':36,
       'BUF':37, 'PWM':38, 'JFK':39, 'CRP':40, 'PIA':41, 'FAT':42, 'SMF':43, 'AUS':44, 'MCI':45,
       'ATL':46, 'JAX':47, 'MFR':48, 'IDA':49, 'MSN':50, 'DCA':51, 'SAT':52, 'CHS':53, 'SBA':54,
       'IND':55, 'CLE':56, 'GSP':57, 'BDL':58, 'RIC':59, 'BFL':60, 'OMA':61, 'RDM':62, 'FLL':63,
       'CID':64, 'TPA':65, 'SYR':66, 'ROC':67, 'TYR':68, 'LAN':69, 'GSO':70, 'EWR':71, 'PBI':72,
       'RSW':73, 'OAK':74, 'PVD':75, 'RNO':76, 'PIT':77, 'ABQ':78, 'MIA':79, 'BWI':80, 'TUL':81,
       'LGA':82, 'LIT':83, 'MSY':84, 'OKC':85, 'ATW':86, 'PNS':87, 'MEM':88, 'TYS':89, 'MHT':90,
       'SAV':91, 'CLT':92, 'GRB':93, 'ABE':94, 'JAN':95, 'OAJ':96, 'FAR':97, 'ERI':98, 'LEX':99,
       'CWA':100, 'TTN':101, 'RDU':102, 'CVG':103, 'BHM':104, 'ACY':105, 'DTW':106, 'RAP':107, 'TUS':108,
       'EAU':109, 'DLH':110, 'FSD':111, 'INL':112, 'SPI':113, 'CLD':114, 'COD':115, 'CMH':116, 'PSC':117,
       'CPR':118, 'ACV':119, 'DAL':120, 'PAH':121, 'MRY':122, 'ESC':123, 'ISN':124, 'PSP':125, 'CAE':126,
       'STL':127, 'BTV':128, 'MTJ':129, 'GCC':130, 'OGG':131, 'SJC':132, 'GUC':133, 'ORF':134, 'MOT':135,
       'MLU':136, 'KOA':137, 'HOU':138, 'MOB':139, 'SAN':140, 'LAW':141, 'PIB':142, 'MGM':143, 'SBP':144,
       'COS':145, 'LAR':146, 'DRO':147, 'BIS':148, 'ITO':149, 'BTR':150, 'HLN':151, 'BZN':152, 'MDW':153,
       'MDT':154, 'SCE':155, 'LIH':156, 'TWF':157, 'BPT':158, 'GPT':159, 'STC':160, 'HPN':161, 'MLB':162,
       'PLN':163, 'CIU':164, 'CAK':165, 'DSM':166, 'BLI':167, 'SHV':168, 'SNA':169, 'ALB':170, 'LNK':171,
       'CMI':172, 'GTF':173, 'EKO':174, 'LGB':175, 'AVL':176, 'HSV':177, 'XNA':178, 'SUX':179, 'HYS':180,
       'MFE':181, 'ISP:':182, 'BUR':183, 'DAB':184, 'DAY':185, 'LFT':186, 'LBE':187, 'ASE':188, 'GUM':189,
       'TVC':190, 'ALO':191, 'TLH':192, 'ELP':193, 'MHK':194, 'IMT':195, 'JNU':196, 'JAC':197, 'MEI':198,
       'DBQ':199, 'GNV':200, 'BRD':201, 'DIK':202, 'SDF':203, 'LBB':204, 'AVP':205, 'SGF':206, 'COU':207,
       'BTM':208, 'ELM':209, 'RKS':210, 'PIH':211, 'SUN':212, 'LWS':213, 'VEL':214, 'STT':215, 'SAF':216,
       'YUM':217, 'FCA':218, 'GRR':219, 'HDN':230, 'ROA':231, 'CHA':232, 'EYW':233, 'MYR':234, 'CRW':235,
       'MQT':236, 'CHO':237, 'GJT':238, 'FWA':239, 'ECP':240, 'EVV':241, 'MSO':242, 'EGE':243, 'AMA':244,
       'MLI':245, 'MBS':246, 'GFK':247, 'GRK':248, 'BIL':249, 'OTZ':250, 'KTN':251, 'STX':252, 'ILM':253,
       'PUB':254, 'RHI':255, 'CDC':256, 'HRL':257, 'SCC':258, 'FNT':259, 'LSE':260, 'MMH':261, 'ACT':262,
       'FSM':263, 'AGS':264, 'CEC':265, 'ICT':266, 'AEX':267, 'DHN':268, 'LRD':269, 'WRG':270, 'PHF':271,
       'CNY':272, 'BRW':273, 'GGG':274, 'AZO':275, 'CLL':276, 'SRQ':277, 'ORH':278, 'FLG':279, 'TRI':280,
       'VLD':281, 'SIT':282, 'BQK':283, 'BMI':284, 'PSG':285, 'FAY':286, 'MKG':287, 'CSG':288, 'MAF':289,
       'EWN':290, 'OME':291, 'CMX':292, 'JMS':293, 'SGU':294, 'RST':295, 'GTR':296, 'BET':297, 'TOL':298,
       'APN':299, 'SMX':300, 'LCH':301, 'RDD':302, 'GCK':303, 'DVL':304, 'GRI':305, 'ABY':306, 'SWF':307,
       'ILG':308, 'JLN':309, 'ADK':310, 'UST':311, 'TXK':312, 'SPS':313, 'ABI':314, 'YAK':315, 'SJT':316,
       'CDV':317, 'OTH':318, 'ADQ':319, 'PPG':320, 'ROW':321, 'HOB':322, 'BGM':323, 'BGR':324, 'ITH':325,
       'ACK':326, 'MVY':327, 'WYS':328, 'DLG':329, 'AKN':330, 'GST':331, 'HYA':332, 'BSM:':333})

# %%
dataset['DESTINATION_AIRPORT']=dataset['DESTINATION_AIRPORT'].map({'ANC':1, 'LAX':2, 'SFO':3, 'SEA':4, 'LAS':5, 'DEN':6, 'SLC':7, 'PDX':8, 'FAI':9,'MSP':10, 'PHX':11, 'SJU':12, 'PBG':13, 'IAG':14, 'PSE':15, 'BQN':16, 'ORD':17, 'GEG':18,
       'HNL':19, 'ONT':20, 'MCO':21, 'BOS':22, 'HIB':23, 'ABR':24, 'DFW':25, 'MKE':26, 'IAH':27,
       'BNA':28, 'BRO':29, 'VPS':30, 'BOI':31, 'BJI':32, 'PHL':33, 'SBN':34, 'EUG':35, 'IAD':36,
       'BUF':37, 'PWM':38, 'JFK':39, 'CRP':40, 'PIA':41, 'FAT':42, 'SMF':43, 'AUS':44, 'MCI':45,
       'ATL':46, 'JAX':47, 'MFR':48, 'IDA':49, 'MSN':50, 'DCA':51, 'SAT':52, 'CHS':53, 'SBA':54,
       'IND':55, 'CLE':56, 'GSP':57, 'BDL':58, 'RIC':59, 'BFL':60, 'OMA':61, 'RDM':62, 'FLL':63,
       'CID':64, 'TPA':65, 'SYR':66, 'ROC':67, 'TYR':68, 'LAN':69, 'GSO':70, 'EWR':71, 'PBI':72,
       'RSW':73, 'OAK':74, 'PVD':75, 'RNO':76, 'PIT':77, 'ABQ':78, 'MIA':79, 'BWI':80, 'TUL':81,
       'LGA':82, 'LIT':83, 'MSY':84, 'OKC':85, 'ATW':86, 'PNS':87, 'MEM':88, 'TYS':89, 'MHT':90,
       'SAV':91, 'CLT':92, 'GRB':93, 'ABE':94, 'JAN':95, 'OAJ':96, 'FAR':97, 'ERI':98, 'LEX':99,
       'CWA':100, 'TTN':101, 'RDU':102, 'CVG':103, 'BHM':104, 'ACY':105, 'DTW':106, 'RAP':107, 'TUS':108,
       'EAU':109, 'DLH':110, 'FSD':111, 'INL':112, 'SPI':113, 'CLD':114, 'COD':115, 'CMH':116, 'PSC':117,
       'CPR':118, 'ACV':119, 'DAL':120, 'PAH':121, 'MRY':122, 'ESC':123, 'ISN':124, 'PSP':125, 'CAE':126,
       'STL':127, 'BTV':128, 'MTJ':129, 'GCC':130, 'OGG':131, 'SJC':132, 'GUC':133, 'ORF':134, 'MOT':135,
       'MLU':136, 'KOA':137, 'HOU':138, 'MOB':139, 'SAN':140, 'LAW':141, 'PIB':142, 'MGM':143, 'SBP':144,
       'COS':145, 'LAR':146, 'DRO':147, 'BIS':148, 'ITO':149, 'BTR':150, 'HLN':151, 'BZN':152, 'MDW':153,
       'MDT':154, 'SCE':155, 'LIH':156, 'TWF':157, 'BPT':158, 'GPT':159, 'STC':160, 'HPN':161, 'MLB':162,
       'PLN':163, 'CIU':164, 'CAK':165, 'DSM':166, 'BLI':167, 'SHV':168, 'SNA':169, 'ALB':170, 'LNK':171,
       'CMI':172, 'GTF':173, 'EKO':174, 'LGB':175, 'AVL':176, 'HSV':177, 'XNA':178, 'SUX':179, 'HYS':180,
       'MFE':181, 'ISP:':182, 'BUR':183, 'DAB':184, 'DAY':185, 'LFT':186, 'LBE':187, 'ASE':188, 'GUM':189,
       'TVC':190, 'ALO':191, 'TLH':192, 'ELP':193, 'MHK':194, 'IMT':195, 'JNU':196, 'JAC':197, 'MEI':198,
       'DBQ':199, 'GNV':200, 'BRD':201, 'DIK':202, 'SDF':203, 'LBB':204, 'AVP':205, 'SGF':206, 'COU':207,
       'BTM':208, 'ELM':209, 'RKS':210, 'PIH':211, 'SUN':212, 'LWS':213, 'VEL':214, 'STT':215, 'SAF':216,
       'YUM':217, 'FCA':218, 'GRR':219, 'HDN':230, 'ROA':231, 'CHA':232, 'EYW':233, 'MYR':234, 'CRW':235,
       'MQT':236, 'CHO':237, 'GJT':238, 'FWA':239, 'ECP':240, 'EVV':241, 'MSO':242, 'EGE':243, 'AMA':244,
       'MLI':245, 'MBS':246, 'GFK':247, 'GRK':248, 'BIL':249, 'OTZ':250, 'KTN':251, 'STX':252, 'ILM':253,
       'PUB':254, 'RHI':255, 'CDC':256, 'HRL':257, 'SCC':258, 'FNT':259, 'LSE':260, 'MMH':261, 'ACT':262,
       'FSM':263, 'AGS':264, 'CEC':265, 'ICT':266, 'AEX':267, 'DHN':268, 'LRD':269, 'WRG':270, 'PHF':271,
       'CNY':272, 'BRW':273, 'GGG':274, 'AZO':275, 'CLL':276, 'SRQ':277, 'ORH':278, 'FLG':279, 'TRI':280,
       'VLD':281, 'SIT':282, 'BQK':283, 'BMI':284, 'PSG':285, 'FAY':286, 'MKG':287, 'CSG':288, 'MAF':289,
       'EWN':290, 'OME':291, 'CMX':292, 'JMS':293, 'SGU':294, 'RST':295, 'GTR':296, 'BET':297, 'TOL':298,
       'APN':299, 'SMX':300, 'LCH':301, 'RDD':302, 'GCK':303, 'DVL':304, 'GRI':305, 'ABY':306, 'SWF':307,
       'ILG':308, 'JLN':309, 'ADK':310, 'UST':311, 'TXK':312, 'SPS':313, 'ABI':314, 'YAK':315, 'SJT':316,
       'CDV':317, 'OTH':318, 'ADQ':319, 'PPG':320, 'ROW':321, 'HOB':322, 'BGM':323, 'BGR':324, 'ITH':325,
       'ACK':326, 'MVY':327, 'WYS':328, 'DLG':329, 'AKN':330, 'GST':331, 'HYA':332, 'BSM:':333})

# %%
dataset.head()
# Out:
#    MONTH  DAY  AIRLINE  ORIGIN_AIRPORT  DESTINATION_AIRPORT  DEPARTURE_DELAY  \
# 0      1    1        1             1.0                  4.0            -11.0
# 1      1    1        2             2.0                 72.0             -8.0
# 2      1    1        3             3.0                 92.0             -2.0
# 3      1    1        2             2.0                 79.0             -5.0
# 4      1    1        1             4.0                  1.0             -1.0
#
#    TAXI_OUT  WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  AIR_TIME  DISTANCE  \
# 0      21.0        15.0           205.0         194.0     169.0      1448
# 1      12.0        14.0           280.0         279.0     263.0      2330
# 2      16.0        34.0           286.0         293.0     266.0      2296
# 3      15.0        30.0           285.0         281.0     258.0      2342
# 4      11.0        35.0           235.0         215.0     199.0      1448
#
#    WHEELS_ON  TAXI_IN  ARRIVAL_TIME  DELAYED
# ...

# %%
X=dataset
Y=dataset['DELAYED']
X=X.drop('DELAYED',axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# %%
from xgboost import XGBClassifier
classifier=XGBClassifier()
classifier.fit(X_train,Y_train)
# Out:
# [23:26:43] WARNING: C:\Jenkins\workspace\xgboost-win64_release_0.90\src\learner.cc:686: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
y_pred=classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
a=accuracy_score(Y_test,y_pred)

# %%
print(a*100)
# Out:
# 89.2186047976815
